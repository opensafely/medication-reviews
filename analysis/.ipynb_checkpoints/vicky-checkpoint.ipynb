# %% [markdown]
# **Medication Reviews in OpenSAFELY**
# August 2022
# V Speed

# %% [markdown]
# The two measures for medication reviews are:
# 1. Structured medication review
# https://www.opencodelists.org/codelist/opensafely/structured-medication-review-nhs-england/5459205f/
# Coding system: SNOMED CT
#
# 2. Medication reviews
# https://www.opencodelists.org/codelist/opensafely/care-planning-medication-review-simple-reference-set-nhs-digital/61b13c39/
# Coding system: SNOMED CT
#
# COULD DO A TABLE FOR THIS
# The top 5 codes used:
# 182836005	Review of medication (procedure) 13.1%
# 88551000000109	Medication review with patient (procedure) 12.22%
# 1239511000000100	Structured medication review (procedure) 9.25 % (Note this is the same as SMR single code)
# 185381007	Repeat medication check (procedure) 8.86 %
# 93311000000106	Medication review of medical notes (procedure) 7.5 %

# %% [markdown]
# *Demographic variables*
# - Sex (Categorical)
# - Age (Age bands)
# - Ethnicity
# - Learning disability
# - Care home status
# - Practice
# - Region
# - Index of multiple deprivation (quintiles)

# %%
def show_image(path):

    img=Image(path)
    display(img)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpllimg
import matplotlib as mpl
import json
import numpy as np
from IPython.display import HTML, display, Markdown, Image
import os

# %% [markdown]
# _Medication Reviews and SMRs stratified by age band._

# %%
show_image("../output/figures/mr_age_band_rate.jpeg")
show_image("../output/figures/smr_age_band_rate.jpeg")

# %% [markdown]
# __Medication Reviews and SMRs stratified by sex.

# %%
show_image("../output/figures/mr_sex_rate.jpeg")
show_image("../output/figures/smr_sex_rate.jpeg")

# %% [markdown]
# __Medication Reviews and SMRs stratified by IMD.
#
# Count of missing data ()

# %%
show_image("../output/figures/mr_imdQ5_rate.jpeg")
show_image("../output/figures/smr_imdQ5_rate.jpeg")

# %% [markdown]
# __Medication Reviews and SMR stratified by ethnicity.

# %%
show_image("../output/figures/mr_ethnicity_rate.jpeg")
show_image("../output/figures/smr_ethnicity_rate.jpeg")

# %% [markdown]
# __Medication Reviews and SMRs stratified by region.

# %%
show_image("../output/figures/mr_region_rate.jpeg")
show_image("../output/figures/smr_region_rate.jpeg")

# %% [markdown]
# __Medication Reviews and SMRs stratified by nursing home resident (SRO method).

# %%
show_image("../output/figures/mr_nhome_rate.jpeg")
show_image("../output/figures/smr_nhome_rate.jpeg")

# %% [markdown]
# __Medication Reviews and SMR stratified by Nursing Home status (5 categories aggregated to binary)

# %%
show_image("../output/figures/mr_care_home_type_rate.jpeg")
show_image("../output/figures/smr_care_home_type_rate.jpeg")

# %% [markdown]
# __Medication Reviews and SMRs stratified by Learning Disability status (1).

# %%
show_image("../output/figures/mr_learning_disability_rate.jpeg")
show_image("../output/figures/smr_learning_disability_rate.jpeg")
